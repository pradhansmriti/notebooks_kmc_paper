# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import matplotlib.image as mpimg
from subprocess import Popen
import glob,os,time,sys,math,shutil
import numpy as np
import re
import pandas as pd
from IPython.display import display,clear_output
from matplotlib.ticker import FormatStrFormatter
from pylab import rcParams
import seaborn as sns
import matplotlib as mpl
from scipy.stats import gaussian_kde,kde,ks_2samp,entropy
timestr=time.strftime("%m%d")
from matplotlib import colormaps
import warnings
warnings.filterwarnings('ignore')

# %%
stdsalt
final_resultn=stdsalt_drug[stdsalt_drug['count']>32]

# %%
plt.plot(final_resultn['Sweep'],final_resultn['average_sweep'])

# %%
markerarraystd=mpl.colormaps['Reds'](np.linspace(0.3,0.8,150))
count=0
for file in with_drug_files[::2]:
    df=pd.read_csv(file,chunksize=10000)
    for chunk in df:
        plt.plot(chunk['sweep'],chunk['NE'],color=markerarraystd[count],alpha=0.8)
    del df
#plt.xscale('log')
print(count)
plt.xlabel('time(in seconds)',fontsize=14)
#plt.xticks(final_resultn['Sweep']*10**(-5))
plt.ylabel('NE',fontsize=14)
plt.title('NE vs time for std salt concentration with drug',fontsize=16)
plt.legend(fontsize=14,loc='lower right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0

# %%
with_drug_files=glob.glob('/home/smriti/BigStorage/figs_movies_KMC/new_runs_2025/allEnergyFiles/SE-DMU--4.5_Rgdrug--15_kd-0.0001/*energy.dat')
for file in with_drug_files[::2]:
    df=pd.read_csv(file,chunksize=10000)
    for chunk in df:
        chunk['NE']=chunk['NE']
        chunk['sweep']=chunk['sweep']*10**(-5)
        chunk.to_csv(file+'_chunk.csv',index=False,mode='a',header=False)
    del df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 for file in with_drug_files[::2]:
#       3     df=pd.read_csv(file,chunksize=10000)
# ----> 4     for chunk in df:
#       5         chunk['NE']=chunk['NE']
#       6         chunk['sweep']=chunk['sweep']*10**(-5)
#
# File ~/miniconda3/envs/mdaenv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1624, in TextFileReader.__next__(self)
#    1622 def __next__(self) -> DataFrame:
#    1623     try:
# -> 1624         return self.get_chunk()
#    1625     except StopIteration:
#    1626         self.close()
#
# File ~/miniconda3/envs/mdaenv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1733, in TextFileReader.get_chunk(self, size)
#    1731         raise StopIteration
#    1732     size = min(size, self.nrows - self._currow)
# -> 1733 return self.read(nrows=size)
#
# ...
